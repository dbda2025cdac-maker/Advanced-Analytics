# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import shapiro

# %%
df = pd.read_csv('../datasets/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
shapiro_test = shapiro(df['Glucose'])
print("Shapiro wilk p-value: ",shapiro_test.pvalue)

if shapiro_test.pvalue<0.05:
    print("Data is not normally distributed")
else:
    print("Data is normally distributed")
# Out:
# Shapiro wilk p-value:  1.9863474999979633e-11
# Data is not normally distributed

# %%
#Generate a QQ Plot for the sample mean 
stats.probplot(df['Glucose'],dist = 'norm', plot = plt)
plt.title('Qq Plot for Sample means')
plt.show()

# %%
#Central Limit Theorem
sample_means = []
n_samples = 100
sample_size = 30

# %%
for _ in range(n_samples):
    sample = df['Glucose'].sample(n=sample_size, replace = True)
    sample_means.append(sample.mean())

# %%
#Plot the distribution for sample means
plt.hist(sample_means, bins = 30, edgecolor = 'k', alpha = 0.7)
plt.title("Distribution of Sample means (n=30)")
plt.xlabel('Sample mean')
plt.ylabel('Frequency')
plt.show()

# %%
#Genrerate QQ Plot for the sample means
stats.probplot(sample_means, dist = 'norm', plot = plt)
plt.title('QQ Plot of Sample means')
plt.show()

# %%
#Perform the shapiro wilk test on the sample means
shapiro_test = stats.shapiro(sample_means)
print("Shapiro wilk p-value: ",shapiro_test.pvalue)
# Out:
# Shapiro wilk p-value:  0.7095385894676923
