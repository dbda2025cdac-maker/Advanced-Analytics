# %%
'''
A courier company delivers parcels in particular areas in 30 minutes. A new GPS system installed has reduced the average time to 28 minutes 
, when 100 trucks were studied, with a sample standard deviation of 4.2 minutes. Run two tailed test and one-tailed test (left tailed)
'''
