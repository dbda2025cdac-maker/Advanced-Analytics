# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('shopping.csv')
print(df.head(10))
print(df.info())
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
# 5           5     17850.0      M  Chicago           12.0         16701.0
# 6           6     17850.0      M  Chicago           12.0         16702.0
# 7           7     17850.0      M  Chicago           12.0         16703.0
# 8           8     17850.0      M  Chicago           12.0         16704.0
# 9           9     17850.0      M  Chicago           12.0         16710.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# ...

# %%
for col in df.columns:
    if df[col].isna().any() :
        print(col)


#Number of values missing in coupon column

null_count = df['Coupon_Status'].isna().sum()

print("Number of null values in coupon columns is: ",null_count)
# Out:
# CustomerID
# Gender
# Location
# Tenure_Months
# Transaction_ID
# Transaction_Date
# Product_SKU
# Product_Description
# Quantity
# Avg_Price
# Delivery_Charges
# Coupon_Status
# GST
# Date
# Offline_Spend
# Online_Spend
# Coupon_Code
# Discount_pct
# Number of null values in coupon columns is:  31

# %%
# import datetime
df['Transaction_Date'] = df['Transaction_Date'].astype('datetime64[ns]')
df.info()
# df = df.to_datetime('Transaction_Date')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           52955 non-null  int64
#  1   CustomerID           52924 non-null  float64
#  2   Gender               52924 non-null  object
#  3   Location             52924 non-null  object
#  4   Tenure_Months        52924 non-null  float64
#  5   Transaction_ID       52924 non-null  float64
#  6   Transaction_Date     52924 non-null  datetime64[ns]
#  7   Product_SKU          52924 non-null  object
#  8   Product_Description  52924 non-null  object
#  9   Product_Category     52955 non-null  object
#  10  Quantity             52924 non-null  float64
#  11  Avg_Price            52924 non-null  float64
#  12  Delivery_Charges     52924 non-null  float64
#  13  Coupon_Status        52924 non-null  object
#  14  GST                  52924 non-null  float64
# ...

# %%
duplicated_transactions = df[df.duplicated(subset = ['Transaction_ID'])]
duplicated_transactions
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 13             13     17850.0      M     Chicago           12.0
# 16             16     17850.0      M     Chicago           12.0
# 18             18     17850.0      M     Chicago           12.0
# 24             24     13047.0      M  California           43.0
# 39             39     12431.0      F  New Jersey           14.0
# ...           ...         ...    ...         ...            ...
# 52950       52950         NaN    NaN         NaN            NaN
# 52951       52951         NaN    NaN         NaN            NaN
# 52952       52952         NaN    NaN         NaN            NaN
# 52953       52953         NaN    NaN         NaN            NaN
# 52954       52954         NaN    NaN         NaN            NaN
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 13            16720.0       2019-01-01  GGOENEBQ078999
# 16            16722.0       2019-01-01  GGOENEBQ078999
# ...

# %%
chicgo_df = df[df['Location'] == 'Chicago']
chicgo_df
# Out:
#        Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0               0     17850.0      M  Chicago           12.0         16679.0
# 1               1     17850.0      M  Chicago           12.0         16680.0
# 2               2     17850.0      M  Chicago           12.0         16696.0
# 3               3     17850.0      M  Chicago           12.0         16699.0
# 4               4     17850.0      M  Chicago           12.0         16700.0
# ...           ...         ...    ...      ...            ...             ...
# 52916       52916     15002.0      M  Chicago           41.0         23798.0
# 52917       52917     15002.0      M  Chicago           41.0         23799.0
# 52918       52918     15002.0      M  Chicago           41.0         23800.0
# 52920       52920     18077.0      M  Chicago           34.0         24250.0
# 52923       52923     13659.0      F  Chicago            8.0         39998.0
#
#       Transaction_Date     Product_SKU  \
# ...

# %%
q6 = df[(df['Gender'] == 'M') & (df['Product_Category'] == 'Nest-USA')]
q6
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 0               0     17850.0      M     Chicago           12.0
# 1               1     17850.0      M     Chicago           12.0
# 2               2     17850.0      M     Chicago           12.0
# 3               3     17850.0      M     Chicago           12.0
# 4               4     17850.0      M     Chicago           12.0
# ...           ...         ...    ...         ...            ...
# 48981       48981     16085.0      M  California           15.0
# 48982       48982     16085.0      M  California           15.0
# 48983       48983     16085.0      M  California           15.0
# 48984       48984     16085.0      M  California           15.0
# 48985       48985     16085.0      M  California           15.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 0             16679.0       2019-01-01  GGOENEBJ079499
# 1             16680.0       2019-01-01  GGOENEBJ079499
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct'],
#       dtype='object')

# %%
#q7
pd.set_option('display.max_columns',None)
print(df[(df['Avg_Price'] > 100) & (df['Quantity'] > 1)])
pd.reset_option('display.max_columns')
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 2               2     17850.0      M     Chicago           12.0
# 6               6     17850.0      M     Chicago           12.0
# 16             16     17850.0      M     Chicago           12.0
# 22             22     17850.0      M     Chicago           12.0
# 23             23     13047.0      M  California           43.0
# ...           ...         ...    ...         ...            ...
# 52088       52088     17880.0      M  California           12.0
# 52089       52089     15555.0      F     Chicago           34.0
# 52091       52091     13102.0      F    New York           10.0
# 52094       52094     17341.0      F    New York           13.0
# 52095       52095     14051.0      M     Chicago            6.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 2             16696.0       2019-01-01  GGOENEBQ078999
# 6             16702.0       2019-01-01  GGOENEBJ079499
# ...

# %%
df.dropna(inplace=True)
df[df['Product_Description'].str.contains("Nest")]
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 0               0     17850.0      M     Chicago           12.0
# 1               1     17850.0      M     Chicago           12.0
# 2               2     17850.0      M     Chicago           12.0
# 3               3     17850.0      M     Chicago           12.0
# 4               4     17850.0      M     Chicago           12.0
# ...           ...         ...    ...         ...            ...
# 52092       52092     13102.0      F    New York           10.0
# 52093       52093     17722.0      F     Chicago           12.0
# 52094       52094     17341.0      F    New York           13.0
# 52095       52095     14051.0      M     Chicago            6.0
# 52096       52096     17827.0      M  California           32.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 0             16679.0       2019-01-01  GGOENEBJ079499
# 1             16680.0       2019-01-01  GGOENEBJ079499
# ...

# %%
#Q9

print(df.groupby('Product_Category')['Avg_Price'].mean('Avg_Price'))
df.groupby('Product_Category')['Avg_Price'].mean('Avg_Price').reset_index()
# Out:
# Product_Category
# Accessories               8.211068
# Android                  15.903488
# Apparel                  19.788995
# Bags                     29.830797
# Bottles                   3.437201
# Drinkware                10.696893
# Gift Cards              111.363270
# Headgear                 15.879624
# Housewares                2.060574
# Lifestyle                 3.860078
# Nest                    194.221074
# Nest-Canada             157.243249
# Nest-USA                124.331850
# Notebooks & Journals     11.758505
# Office                    3.770012
# Waze                      6.607852
# Name: Avg_Price, dtype: float64
#         Product_Category   Avg_Price
# 0            Accessories    8.211068
# 1                Android   15.903488
# 2                Apparel   19.788995
# 3                   Bags   29.830797
# 4                Bottles    3.437201
# 5              Drinkware   10.696893
# 6             Gift Cards  111.363270
# 7               Headgear   15.879624
# ...

# %%
# Q10
print(df.groupby('Location')['Transaction_ID'].nunique())
print(df.groupby('Location')['Transaction_ID'].count())
# Out:
# Location
# California       7869
# Chicago          9067
# New Jersey       2262
# New York         5487
# Washington DC    1407
# Name: Transaction_ID, dtype: int64
# Location
# California       16008
# Chicago          18240
# New Jersey        4470
# New York         11097
# Washington DC     2709
# Name: Transaction_ID, dtype: int64

# %%
# Q11
df.groupby('Gender')[['Offline_Spend','Online_Spend']].sum()
# Out:
#         Offline_Spend  Online_Spend
# Gender
# F          93825600.0   62291544.23
# M          54944900.0   37200278.87

# %%
# Q11
df.groupby('Coupon_Status')['Transaction_ID'].count()
# Out:
# Coupon_Status
# Clicked     26720
# Not Used     8026
# Used        17778
# Name: Transaction_ID, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct'],
#       dtype='object')

# %%
df['Total_Transaction_Value'] = df['Quantity'] * df['Avg_Price'] + df['GST'] + df['Delivery_Charges']
df.head()
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
# ...

# %%
pd.pivot(data = df, columns='Location', values= 'Quantity')
# Out:
# Location  California  Chicago  New Jersey  New York  Washington DC
# 0                NaN      1.0         NaN       NaN            NaN
# 1                NaN      1.0         NaN       NaN            NaN
# 2                NaN      2.0         NaN       NaN            NaN
# 3                NaN      1.0         NaN       NaN            NaN
# 4                NaN      1.0         NaN       NaN            NaN
# ...              ...      ...         ...       ...            ...
# 52919            1.0      NaN         NaN       NaN            NaN
# 52920            NaN      1.0         NaN       NaN            NaN
# 52921            1.0      NaN         NaN       NaN            NaN
# 52922            1.0      NaN         NaN       NaN            NaN
# 52923            NaN      1.0         NaN       NaN            NaN
#
# [52524 rows x 5 columns]
