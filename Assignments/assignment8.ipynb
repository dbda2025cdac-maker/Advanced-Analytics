# %%
#Nobel dataset
# 1. P(winning a nobel prize in physics given the lautrete is female) - 0.05
# 2. P(Winning a nobel price in literature given that laureate was born in usa) - 0.03

# %%
import pandas as pd
df = pd.read_csv("../datasets/nobel.csv")
pd.set_option('display.max_columns',None)
df.head()
# Out:
#    awardYear           category  \
# 0       2001  Economic Sciences
# 1       1975            Physics
# 2       2004          Chemistry
# 3       1982          Chemistry
# 4       1979            Physics
#
#                                     categoryFullName  sortOrder portion  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...          2  01-Mar
# 1                         The Nobel Prize in Physics          1  01-Mar
# 2                       The Nobel Prize in Chemistry          1  01-Mar
# 3                       The Nobel Prize in Chemistry          1       1
# 4                         The Nobel Prize in Physics          2  01-Mar
#
#    prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 0     10000000             12295082  10/10/2001    received
# 1       630000              3404179  17/10/1975    received
# 2     10000000             11762861  06/10/2004    received
# 3      1150000              3102518  18/10/1982    received
# ...

# %%
# pd.set_option('display.max_rows',None)
print(df.info())
# pd.reset_option('display.max_rows')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   awardYear                   950 non-null    int64
#  1   category                    950 non-null    object
#  2   categoryFullName            950 non-null    object
#  3   sortOrder                   950 non-null    int64
#  4   portion                     950 non-null    object
#  5   prizeAmount                 950 non-null    int64
#  6   prizeAmountAdjusted         950 non-null    int64
#  7   dateAwarded                 533 non-null    object
#  8   prizeStatus                 950 non-null    object
#  9   motivation                  950 non-null    object
#  10  categoryTopMotivation       20 non-null     object
#  11  award_link                  950 non-null    object
#  12  id                          950 non-null    int64
# ...

# %%
total_winners = len(df)
female_winners = len(df[df['gender'] == 'female'])

# P_winning_given_female_winner = 
print(female_winners/total_winners)
# Out:
# 0.056842105263157895
