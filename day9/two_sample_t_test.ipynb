# %% [markdown]
# # Two independent sample t test. chekc whether two gorups/samples are statustucally similar/different

# %%
import pandas as pd
from scipy import stats

# %%
data = pd.read_csv('../datasets/Mall_customers.csv')
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
male_spending = data[data['Genre'] == "Male"]['Spending Score (1-100)']
female_spending = data[data['Genre'] == "Female"]['Spending Score (1-100)']

# %%
male_spending = male_spending.sample(n=30, replace = False)
female_spending = female_spending.sample(n=30, replace = False)

# %%
t_statistic, p_value = stats.ttest_ind(male_spending, female_spending)

# %%
alpha= 0.05
print(f"P-Value :", p_value)
# Out:
# P-Value : 0.37139615069878307

# %%
if p_value < alpha:
    print("Rejected H0")
else:
    print("Do not reject H0")
# Out:
# Do not reject H0
