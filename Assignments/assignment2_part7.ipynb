# %%
'''
A battery manufacturer claims that a battery which used to run for 30 hours now runs for more than 30 hours due to a new tech,
200 batteries were studied. Avg battery time found to be is 29.5 hours with a standard deviation of 8 hourss. Run a one tailed test
(right tailed)
'''
