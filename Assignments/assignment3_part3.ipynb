# %%
#Perform naive bayes classification algo and logistic regression algo to predict a bank customer would 
#"churn" i.e. close an account using bank cusotomer churn prediction. 
# Perform encoding and scaling as appropriate. Handle nulls if present
